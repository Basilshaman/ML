# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn import tree
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
data=pd.read_csv('diabetes2.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x=data.drop(['Outcome'],axis=1)
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y=data['Outcome']
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=5)

# %%
scaler=MinMaxScaler()
scaler
# Out:
# MinMaxScaler()

# %%
x_train_m= scaler.fit_transform(x_train)
x_train_m
# Out:
# array([[0.70588235, 0.70351759, 0.67213115, ..., 0.58420268, 0.19214347,
#         0.61666667],
#        [0.47058824, 0.60301508, 0.63934426, ..., 0.37257824, 0.14133219,
#         0.71666667],
#        [0.05882353, 0.44221106, 0.24590164, ..., 0.81967213, 0.17847993,
#         0.08333333],
#        ...,
#        [0.11764706, 0.77889447, 0.60655738, ..., 0.39642325, 0.15157985,
#         0.1       ],
#        [0.29411765, 0.52763819, 0.59016393, ..., 0.54992548, 0.03458582,
#         0.11666667],
#        [0.23529412, 0.42713568, 0.47540984, ..., 0.414307  , 0.09735269,
#         0.11666667]])

# %%
len(x_train_m)
# Out:
# 763

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 110            3      171             72             33      135  33.3
# 221            2      158             90              0        0  31.6
# 124            0      113             76              0        0  33.3
# 112            1       89             76             34       37  31.2
# 42             7      106             92             18        0  22.7
#
#      DiabetesPedigreeFunction  Age
# 110                     0.199   24
# 221                     0.805   66
# 124                     0.278   23
# 112                     0.192   23
# 42                      0.235   48

# %%
x_test_m=scaler.fit_transform(x_test)
x_test_m
# Out:
# array([[0.42857143, 1.        , 0.        , 0.97058824, 1.        ,
#         1.        , 0.01141925, 0.02325581],
#        [0.28571429, 0.84146341, 0.9       , 0.        , 0.        ,
#         0.83962264, 1.        , 1.        ],
#        [0.        , 0.29268293, 0.2       , 0.        , 0.        ,
#         1.        , 0.14029364, 0.        ],
#        [0.14285714, 0.        , 0.2       , 1.        , 0.27407407,
#         0.80188679, 0.        , 0.        ],
#        [1.        , 0.20731707, 1.        , 0.52941176, 0.        ,
#         0.        , 0.07014682, 0.58139535]])

# %%
model=DecisionTreeClassifier(max_depth=3)

# %%
model=DecisionTreeClassifier(max_depth=5)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
model.fit(x_train_m,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
y_predict=model.predict(x_test)
y_predict
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# array([0, 1, 1, 0, 1], dtype=int64)

# %%
y_predict_m=model.predict(x_test_m)
y_predict_m
# Out:
# array([0, 1, 1, 1, 1], dtype=int64)

# %%
accuracy_score=(y_test,y_predict)
accuracy_score
# Out:
# (110    1
#  221    1
#  124    1
#  112    0
#  42     0
#  Name: Outcome, dtype: int64,
#  array([0, 1, 1, 0, 1], dtype=int64))

# %%
accuracy_score_m=(y_test,y_predict_m)
accuracy_score_m
# Out:
# (110    1
#  221    1
#  124    1
#  112    0
#  42     0
#  Name: Outcome, dtype: int64,
#  array([0, 1, 1, 1, 1], dtype=int64))

# %%
print(classification_report(y_test,y_predict_m))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.50      0.67      0.57         3
#
#     accuracy                           0.40         5
#    macro avg       0.25      0.33      0.29         5
# weighted avg       0.30      0.40      0.34         5

# %%
len(y_test)
# Out:
# 5

# %%
cm_m=confusion_matrix(y_test,y_predict_m)
cm_m
# Out:
# array([[0, 2],
#        [1, 2]], dtype=int64)

# %%
cm=confusion_matrix(y_test,y_predict)
cm
# Out:
# array([[1, 1],
#        [1, 2]], dtype=int64)

# %%
import seaborn as sns

# %%
sns.heatmap(cm,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
sns.heatmap(cm_m,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
feature=list(x.columns)
tree.plot_tree(model,feature_names=feature,filled=True)
plt.show()

# %%
fig=plt.figure(figsize=(50,50))
tree.plot_tree(model,feature_names=feature,filled=True)
plt.show()
